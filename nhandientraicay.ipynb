# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

folder= '/content/drive/MyDrive/dulieu/traicay/'
for i in range(9):
  plt.subplot(330+i+1)
  filename = folder+'quaoi'+str(i+1)+'.bmp'
  image = imread(filename)
  plt.imshow(image)
plt.show()

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img, img_to_array

folder= '/content/drive/MyDrive/dulieu/traicay/'

photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('dualeo'):
    output = 0
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('quabo'):
    output = 1
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('quachuoi'):
    output = 2
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('quadau'):
    output = 3
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('quadua'):
    output = 4
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('quaduaa'):
    output = 5
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('quamangcut'):
    output = 6
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('quamit'):
    output = 7
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('quanhan'):
    output = 8
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('quaoi'):
    output = 9
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

photos = asarray(photos)
labels = asarray(labels)
print(photos.shape,labels.shape)

save('10TraiCay_photos.npy', photos)
save('10TraiCay_labels.npy', labels)
# Out:
# (110, 200, 200, 3) (110,)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten # BatchNormalization: để dùng GPU ko lỗi

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(200, 200, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))


model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
 history = model.fit(photos, labels, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 12s 146ms/step - loss: 4021.3181 - accuracy: 0.1273
# Epoch 2/50
# 4/4 [==============================] - 0s 37ms/step - loss: 1385.5757 - accuracy: 0.1636
# Epoch 3/50
# 4/4 [==============================] - 0s 38ms/step - loss: 85.6883 - accuracy: 0.2273
# Epoch 4/50
# 4/4 [==============================] - 0s 38ms/step - loss: 18.8642 - accuracy: 0.3455
# Epoch 5/50
# 4/4 [==============================] - 0s 39ms/step - loss: 3.2399 - accuracy: 0.3818
# Epoch 6/50
# 4/4 [==============================] - 0s 36ms/step - loss: 1.1273 - accuracy: 0.6091
# Epoch 7/50
# 4/4 [==============================] - 0s 39ms/step - loss: 1.1055 - accuracy: 0.6364
# Epoch 8/50
# 4/4 [==============================] - 0s 37ms/step - loss: 0.7140 - accuracy: 0.7636
# Epoch 9/50
# 4/4 [==============================] - 0s 40ms/step - loss: 0.6421 - accuracy: 0.7455
# Epoch 10/50
# ...

# %%
model.evaluate(photos,labels)
# Out:
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1305 - accuracy: 0.9091
# [0.1304648220539093, 0.9090909361839294]

# %%
model.save('10TraiCay_Final.h5')

# %%
from keras.models import load_model
models=load_model('10TraiCay_Final.h5')

# %%
classes = ["dualeo","quabo","quachuoi","quadau","quadua","quaduaa","quamangcut","quamit","quanhan","quaoi"]

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array

img = load_img('../content/drive/MyDrive/dulieu/traicay/quanhan10.bmp', target_size=(200,200))
plt.imshow(img)

# %%
import numpy as np
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.10003504 0.09731191 0.09766139 0.09474353 0.10326764 0.10370564
#   0.09954361 0.09901708 0.10618332 0.09853088]]
# 'quanhan'
